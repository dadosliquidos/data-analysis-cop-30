# %%
import pandas as pd
from src.database.database import DB
from dotenv import load_dotenv
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import os

# %% [markdown]
# LINK DO POST

# %%
# link do post

link = 'https://www.instagram.com/doldiarioonline/p/DGDmjvbRGtu/'

# %%
#bando de dados
load_dotenv()
con = DB.conexao()
TABLE_P = os.getenv('TABLE_P')
TABLE_W_S = os.getenv('TABLE_W_S')

# %%
query = f'''
select 
	p.data_post,
    p.nome_pagina,
    cs.sentimento
from {TABLE_P} p
inner join {TABLE_W_S} cs on p.id_posts = cs.posts_id_posts
where p.link = '{link}';
'''
df = pd.read_sql(query,con)
df['qtde'] = 1

display(df)
# Out:
# C:\Users\jgust\AppData\Local\Temp\ipykernel_13704\3150828178.py:10: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query,con)
#       data_post            nome_pagina  \
# 0    2025-02-12  Diário online do Pará
# 1    2025-02-12  Diário online do Pará
# 2    2025-02-12  Diário online do Pará
# 3    2025-02-12  Diário online do Pará
# 4    2025-02-12  Diário online do Pará
# ..          ...                    ...
# 109  2025-02-12  Diário online do Pará
# 110  2025-02-12  Diário online do Pará
# 111  2025-02-12  Diário online do Pará
# 112  2025-02-12  Diário online do Pará
# 113  2025-02-12  Diário online do Pará
#
#                                         sentimento  qtde
# 0    I'm ready to classify the sentiment of the co     1
# 1                                         Negativo     1
# 2                                         Negativo     1
# 3                                         Positivo     1
# 4                                         Positivo     1
# ..                                             ...   ...
# 109                                       Positivo     1
# 110                                       Negativo     1
# 111                                       Negativo     1
# 112                                       Negativo     1
# 113                                       Positivo     1
#
# [114 rows x 4 columns]

# %% [markdown]
# Gráfico de barras

# %%
df_tratato = df.groupby(by=['data_post','sentimento','nome_pagina']).sum( ).reset_index()
fig, ax = plt.subplots()
barras =ax.bar(df_tratato['sentimento'],df_tratato['qtde'])
ax.bar_label(barras)
ax.set_xlabel('Polarização')
ax.set_title('Análise de Sentimentos')
plt.show()

# %% [markdown]
# Nuvem de Palavras

# %%
texto = 'joao gustavo carvalho de jesus jesus jesus joao joao gustavo gus gus gus carvalho'
nuvem_de_palavras = WordCloud().generate(texto)

fig, ax = plt.subplots()
ax.imshow(nuvem_de_palavras,interpolation='bilinear')

ax.set_axis_off()
